# %% [markdown]
# <a href="https://colab.research.google.com/github/yasiruKodikara/10X-frontend/blob/main/NaiveBayes_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/MachineLearningDataSets/kyphosis.csv')

# %%
data.head(5)
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
data.shape
# Out:
# (81, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
import seaborn as sns
sns.pairplot(data,hue='Kyphosis')

# %%
sns.countplot(data['Kyphosis'])
# Out:
# <Axes: xlabel='count', ylabel='Kyphosis'>

# %%
X = data.drop('Kyphosis',axis=1)
y = data['Kyphosis']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)

# %%
X_train.shape
# Out:
# (56, 3)

# %% [markdown]
# # Naive Bayes

# %% [markdown]
# we are using here the gaussian NB because of there are continous data in the data set.

# %%
from sklearn.naive_bayes import GaussianNB
NB = GaussianNB()
NB.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
pred = NB.predict(X_test)
pred,y_test
# Out:
# (array(['absent', 'absent', 'present', 'absent', 'absent', 'absent',
#         'absent', 'absent', 'absent', 'absent', 'absent', 'present',
#         'absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#         'absent', 'present', 'absent', 'absent', 'absent', 'absent',
#         'present'], dtype='<U7'),
#  22    present
#  27     absent
#  61    present
#  13     absent
#  71     absent
#  74     absent
#  30     absent
#  55     absent
#  53     absent
#  26     absent
#  50     absent
#  42     absent
#  48    present
#  33     absent
#  73     absent
#  2     present
#  57    present
#  66     absent
#  41     absent
#  3      absent
#  69     absent
#  7      absent
#  76    present
#  80     absent
#  40    present
#  Name: Kyphosis, dtype: object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.72
